# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt  # Added this import for plotting

# Read data from a CSV file
data = pd.read_csv("teen_phone_addiction_dataset.csv")

# Generate a random sample of the data
sample_size = 1000
sample = data.sample(n=sample_size, replace=False, random_state=42)
sample
# Out:
#         ID               Name  Age  Gender          Location School_Grade  \
# 1801  1802  Garrett Gallagher   13    Male    West Shawnfort         12th
# 1190  1191    Phillip Stewart   18    Male          New Cory         11th
# 1817  1818      Douglas Lucas   18  Female       Stewartbury         10th
# 251    252      Anne Gonzales   14    Male          Lisaland          9th
# 2505  2506      Beverly Hardy   19    Male   North Craigtown          9th
# ...    ...                ...  ...     ...               ...          ...
# 618    619  Margaret Martinez   14    Male     East Lisabury          7th
# 406    407      Ray Henderson   19    Male     Port Kimberly         11th
# 1157  1158   Stephen Mcdonald   17  Female  Port Jasminetown         11th
# 1068  1069      Kim Rodriguez   15   Other       Rittershire         12th
# 1133  1134     Joshua Hendrix   17   Other       East Wesley         11th
#
#       Daily_Usage_Hours  Sleep_Hours  Academic_Performance  \
# ...

# %%
def Desc_stat(ds, var):


    
    mean = ds[var].mean()
    median = ds[var].median()
    mode = ds[var].mode()[0] 
    minimum = ds[var].min()
    maximum = ds[var].max()
    range_v = ds[var].max() - ds[var].min()
    std_dev = ds[var].std()
    variance = ds[var].var()
    skew = ds[var].skew()
    kurtosis = ds[var].kurt()
    count = ds[var].count()
    Quart = [
        ds[var].quantile(0),
        ds[var].quantile(0.25),
        ds[var].quantile(0.50),
        ds[var].quantile(0.75),
        ds[var].quantile(1),
        ds[var].quantile(0.75) - ds[var].quantile(0.25)
    ]

    summary = {
        "Average ": mean,
        "Median ": median,
        "Mode ": mode,
        "Minimum ": minimum,
        "Maximim ": maximum,
        "Range ": range_v,
        "Std Dev": std_dev,
        "Variance": variance,
        "Skewness": skew,
        "Kurtosis": kurtosis,
        "Minimum": Quart[0],
        "25th Pecentile": Quart[1],
        "50th Pecentile": Quart[2],
        "75th Pecentile": Quart[3],
        "Maximum": Quart[4],
        "Inter Quartile Range": Quart[5],
        "Count ": count
    }

    return summary


Desc_stat(data, "Addiction_Level")
# Out:
# {'Average ': np.float64(8.8819),
#  'Median ': 10.0,
#  'Mode ': np.float64(10.0),
#  'Minimum ': 1.0,
#  'Maximim ': 10.0,
#  'Range ': 9.0,
#  'Std Dev': 1.60959808399404,
#  'Variance': 2.590805991997285,
#  'Skewness': np.float64(-1.5419700052812306),
#  'Kurtosis': np.float64(1.9027804134720712),
#  'Minimum': np.float64(1.0),
#  '25th Pecentile': np.float64(8.0),
#  '50th Pecentile': np.float64(10.0),
#  '75th Pecentile': np.float64(10.0),
#  'Maximum': np.float64(10.0),
#  'Inter Quartile Range': np.float64(2.0),
#  'Count ': np.int64(3000)}

# %%
# create a scatter plot for Student ID Vs Final
sample.plot.scatter(x = 'Addiction_Level', y = 'Daily_Usage_Hours', s = 100, c = 'red');

# %%
sample = pd.read_csv("teen_phone_addiction_dataset.csv")
plt.hist(sample['Sleep_Hours'], bins=7, edgecolor='black')

sample = data.sample(n=sample_size, replace=False, random_state=42)

# add labels and title
plt.xlabel('Hours of Sleep')
plt.ylabel('Frequency')
plt.title('Distribution of Sleep Hours')

# display the plot
plt.show()

# %%
# create a box plot
sns.boxplot(x=sample['Sleep_Hours'])

sample = data.sample(n=sample_size, replace=False, random_state=42)
# add labels and title
plt.xlabel('Hours')
plt.title('Distribution of Sleep Hours')

# display the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Set up the data
genders = ['Male', 'Female', 'Other']
# Example frequencies - you can replace these with your actual data
frequencies = [450, 480, 70]

# Light green color palette
colors = ['#a8e6cf', '#a8e6cf', '#a8e6cf']  # Same light green for all bars
# Alternative: different shades of light green
# colors = ['#c1e1c1', '#a8e6cf', '#b5e8d4']

# Create the visualization
plt.figure(figsize=(10, 6))
bars = plt.bar(genders, frequencies, color=colors, edgecolor='#2d5a27', linewidth=1.2)

# Customize the chart with green theme
plt.title('Gender Distribution in Sample (n=1000)', fontsize=16, fontweight='bold', color='#2d5a27')
plt.xlabel('Gender', fontsize=12, color='#2d5a27')
plt.ylabel('Frequency', fontsize=12, color='#2d5a27')

# Add value labels on top of each bar
for bar, frequency in zip(bars, frequencies):
    plt.text(bar.get_x() + bar.get_width()/2, bar.get_height() + 5, 
             str(frequency), ha='center', va='bottom', fontweight='bold', color='#2d5a27')

# Set y-axis limit to show up to 1000
plt.ylim(0, 1000)

# Customize ticks and grid
plt.tick_params(colors='#2d5a27')
plt.grid(axis='y', alpha=0.3, color='#c1e1c1')

# Set face color for light green background
plt.gca().set_facecolor('#f0f8f0')

# Display the chart
plt.tight_layout()
plt.show()

# Print summary statistics
total = sum(frequencies)
print(f"Total sample size: {total}")
for gender, freq in zip(genders, frequencies):
    percentage = (freq / total) * 100
    print(f"{gender}: {freq} ({percentage:.1f}%)")
# Out:
# Total sample size: 1000
# Male: 450 (45.0%)
# Female: 480 (48.0%)
# Other: 70 (7.0%)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10,8))
correlation_matrix= sample.corr(numeric_only=True)
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Heat Map: Correlation Between indices")
plt.show()

# %%
#Spearman Rank Correlation
import pandas as pd
from scipy.stats import spearmanr

# Load the dataset
file_path = "Marks.csv"
df = pd.read_csv(file_path)

# Drop rows with NaN values for Project and Final
data = df[['Project', 'Final']].dropna()

# Perform Spearman's Correlation Test
r, p_value = spearmanr(data['Project'], data['Final'])
df_spearman = len(data) - 2
print("Spearman's Correlation Test Results:")
print(f"Spearman's Correlation Coefficient (r): {r:.4f}")
print(f"P-Value: {p_value:.4f}")
print(f"Degrees of Freedom: {df_spearman}")

# Interpretation
if p_value < 0.05:
    print("\nConclusion: Since the p-value is less than 0.05, we reject the null hypothesis.")
    print("There is a statistically significant correlation between Project and Final marks.")
else:
    print("\nConclusion: Since the p-value is greater than 0.05, we accept the null hypothesis.")
    print("There is no statistically significant correlation between Project and Final marks.")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[25], line 7
#       5 # Load the dataset
#       6 file_path = "Marks.csv"
# ----> 7 df = pd.read_csv(file_path)
#       9 # Drop rows with NaN values for Project and Final
#      10 data = df[['Project', 'Final']].dropna()
#
# ...

# %%
#Spearman Rank Correlation
import pandas as pd
from scipy.stats import spearmanr


# Drop rows with NaN values for Project and Final
sample = sample[['Addiction_Level', 'Daily_Usage_Hours']].dropna()

# Perform Spearman's Correlation Test
r, p_value = spearmanr(sample['Addiction_Level'], sample['Daily_Usage_Hours'])
df_spearman = len(sample) - 2
print("Spearman's Correlation Test Results:")
print(f"Spearman's Correlation Coefficient (r): {r:.4f}")
print(f"P-Value: {p_value:.4f}")
print(f"Degrees of Freedom: {df_spearman}")

# Interpretation
if p_value < 0.05:
    print("\nConclusion: Since the p-value is less than 0.05, we reject the null hypothesis.")
    print("There is a statistically significant correlation between Time_on_Gaming and Time_on_Education.")
else:
    print("\nConclusion: Since the p-value is greater than 0.05, we accept the null hypothesis.")
    print("There is no statistically significant correlation between Time_on_Gaming and Time_on_Education.")
# Out:
# Spearman's Correlation Test Results:
# Spearman's Correlation Coefficient (r): 0.6262
# P-Value: 0.0000
# Degrees of Freedom: 998
#
# Conclusion: Since the p-value is less than 0.05, we reject the null hypothesis.
# There is a statistically significant correlation between Time_on_Gaming and Time_on_Education.

# %%
sample
# Out:
#       Addiction_Level  Daily_Usage_Hours
# 1801             10.0                5.6
# 1190             10.0                5.1
# 1817             10.0                8.0
# 251               9.0                3.0
# 2505             10.0                4.5
# ...               ...                ...
# 618               9.7                4.7
# 406               8.1                5.6
# 1157              9.1                5.8
# 1068             10.0                7.8
# 1133              8.8                4.8
#
# [1000 rows x 2 columns]

# %%
numbers_only = data[['Addiction_Level', 'Weekend_Usage_Hours', 'Family_Communication', 'Time_on_Education', 'Time_on_Gaming', 'Time_on_Social_Media', 'Apps_Used_Daily', 'Phone_Checks_Per_Day', 'Screen_Time_Before_Bed']]
numbers_only
# Out:
#       Addiction_Level  Weekend_Usage_Hours  Family_Communication  \
# 0                10.0                  8.7                     4
# 1                10.0                  5.3                     2
# 2                 9.2                  5.7                     6
# 3                 9.8                  3.0                     8
# 4                 8.6                  3.7                    10
# ...               ...                  ...                   ...
# 2995              9.8                  9.4                     8
# 2996              5.5                  5.2                     9
# 2997              6.2                  5.9                     9
# 2998             10.0                  6.1                     4
# 2999              6.3                  5.1                     7
#
#       Time_on_Education  Time_on_Gaming  Time_on_Social_Media  \
# 0                   1.2             1.7                   3.6
# ...

# %%
numbers_only.corr(method="pearson")
# Out:
#                         Addiction_Level  Weekend_Usage_Hours  \
# Addiction_Level                1.000000            -0.013049
# Weekend_Usage_Hours           -0.013049             1.000000
# Family_Communication          -0.010482             0.024039
# Time_on_Education             -0.000586            -0.023558
# Time_on_Gaming                 0.273060             0.028203
# Time_on_Social_Media           0.306578            -0.014402
# Apps_Used_Daily                0.319287            -0.028933
# Phone_Checks_Per_Day           0.246342            -0.020479
# Screen_Time_Before_Bed         0.013784             0.041958
#
#                         Family_Communication  Time_on_Education  \
# Addiction_Level                    -0.010482          -0.000586
# Weekend_Usage_Hours                 0.024039          -0.023558
# Family_Communication                1.000000           0.008757
# Time_on_Education                   0.008757           1.000000
# ...

# %%
# Verification code that was run
missing_counts = data.isnull().sum()
print("Total missing values in dataset:", missing_counts.sum())
print("\nDetailed breakdown:")
print(missing_counts)
# Out:
# Total missing values in dataset: 0
#
# Detailed breakdown:
# ID                        0
# Name                      0
# Age                       0
# Gender                    0
# Location                  0
# School_Grade              0
# Daily_Usage_Hours         0
# Sleep_Hours               0
# Academic_Performance      0
# Social_Interactions       0
# Exercise_Hours            0
# Anxiety_Level             0
# Depression_Level          0
# Self_Esteem               0
# Parental_Control          0
# Screen_Time_Before_Bed    0
# Phone_Checks_Per_Day      0
# Apps_Used_Daily           0
# Time_on_Social_Media      0
# Time_on_Gaming            0
# Time_on_Education         0
# Phone_Usage_Purpose       0
# Family_Communication      0
# Weekend_Usage_Hours       0
# Addiction_Level           0
# dtype: int64

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

dataset = pd.read_csv('teen_phone_addiction_dataset.csv')

# Daily Usage Hours (index of the column)
X = dataset.iloc[:, [6]].values      # Daily_Usage_Hours
y = dataset.iloc[:, -1].values       # Addiction_Level

print(X)
print(y)
# Out:
# [[4. ]
#  [5.5]
#  [5.8]
#  ...
#  [3.2]
#  [6.7]
#  [3.5]]
# [10.  10.   9.2 ...  6.2 10.   6.3]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size = 1/3, random_state = 0)

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = regressor.predict(X_test)
np.set_printoptions(precision=2)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))
# Out:
# [[ 7.64  5.4 ]
#  [10.62 10.  ]
#  [ 9.79 10.  ]
#  ...
#  [ 8.62  9.8 ]
#  [ 9.2  10.  ]
#  [ 7.2   8.5 ]]

# %%
regressor.predict([[6.6]])
# Out:
# array([9.65])

# %%
y_pred = regressor.predict(X_test)
print(X_test)
print(y_pred)
344
# Out:
# [[ 2.5]
#  [ 8.6]
#  [ 6.9]
#  [ 8.1]
#  [ 4.3]
#  [ 5.4]
#  [ 7.3]
#  [ 8.1]
#  [ 2.4]
#  [ 8.4]
#  [ 5.1]
#  [ 6.1]
#  [ 4.2]
#  [ 4.7]
#  [ 8. ]
#  [ 3.9]
#  [ 5.3]
#  [ 6.2]
#  [ 6.2]
#  [ 4.7]
#  [ 2.6]
#  [ 6.2]
#  [ 4.4]
#  [ 4. ]
#  [ 4.6]
#  [ 7.4]
#  [ 4.6]
#  [ 8.2]
#  [ 4.3]
#  [ 2.7]
#  [ 4.9]
#  [ 4.8]
#  [ 6.6]
#  [ 5.3]
#  [ 3.7]
#  [ 4.1]
#  [ 4.1]
#  [ 7.2]
#  [ 5.3]
#  [ 5.6]
#  [ 7.3]
#  [ 9.4]
#  [ 4.7]
#  [ 6.2]
#  [ 4.3]
#  [ 7.3]
#  [ 5.2]
#  [ 9.8]
#  [ 4.1]
#  [ 5.7]
#  [ 6.6]
#  [ 5.2]
#  [ 4. ]
#  [ 4.1]
#  [ 8.3]
#  [ 6.6]
#  [ 7.4]
#  [ 5.1]
#  [ 1.2]
#  [ 5.7]
#  [ 3.8]
#  [ 7.3]
#  [ 5.5]
#  [ 2.8]
#  [ 4.4]
#  [ 8.2]
#  [ 6.2]
#  [ 1.7]
#  [ 5.4]
#  [ 3.4]
#  [ 6.3]
#  [ 3.9]
#  [ 7.5]
#  [ 5.9]
#  [ 7.7]
#  [ 7.4]
#  [ 5. ]
#  [ 6.2]
#  [ 3.5]
#  [ 7.6]
#  [ 1.3]
#  [ 7.1]
#  [ 4.4]
#  [ 3.5]
#  [ 7.9]
#  [ 5.7]
#  [ 7.1]
#  [ 6.6]
#  [ 6.1]
#  [ 7. ]
#  [ 7.5]
#  [ 3.2]
#  [ 3. ]
#  [ 7.5]
#  [ 5.4]
#  [ 3.4]
#  [ 2.4]
#  [ 4.7]
#  [ 3.8]
#  [ 5.4]
# ...

# %%
plt.scatter(X_train, y_train, color='red')
plt.plot(X_train, regressor.predict(X_train), color='black')
plt.title('Daily Usage Hours vs Addiction Level (Training Set)')
plt.xlabel('Daily Usage Hours')
plt.ylabel('Addiction Level')
plt.show()

# %%
plt.scatter(X_test, y_test, color='orange')
plt.plot(X_train, regressor.predict(X_train), color='Black')
plt.title('Daily Usage Hours vs Addiction Level (Test Set)')
plt.xlabel('Daily Usage Hours')
plt.ylabel('Addiction Level')
plt.show()

# %%
print(regressor.coef_)
print(regressor.intercept_)
# Out:
# [0.49]
# 6.411470210368675

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

dataset = pd.read_csv('teen_phone_addiction_dataset.csv')

# Daily Usage Hours (index of the column)
X = dataset.iloc[:, [15, 7, 6, 18]].values
y = dataset.iloc[:, -1].values       # Addiction_Level

print(X)
print(y)
# Out:
# [[1.4 6.1 4.  3.6]
#  [0.9 6.5 5.5 1.1]
#  [0.5 5.5 5.8 0.3]
#  ...
#  [0.2 6.5 3.2 2.4]
#  [1.6 7.5 6.7 1.7]
#  [0.6 6.9 3.5 0. ]]
# [10.  10.   9.2 ...  6.2 10.   6.3]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size = 0.2, random_state = 0
)

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = regressor.predict(X_test)
np.set_printoptions(precision = 2)
print(np.concatenate(
    (y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)), 1
))
# Out:
# [[ 6.89  5.4 ]
#  [11.03 10.  ]
#  [ 9.77 10.  ]
#  ...
#  [ 9.29 10.  ]
#  [ 7.46  8.3 ]
#  [ 9.26 10.  ]]

# %%
print(regressor.predict([[2, 7, 5, 3]]))
# Out:
# [9.02]

# %%
from sklearn.metrics import r2_score
r2_score(y_test, y_pred)
# Out:
# 0.39842879562459754

# %%
print(regressor.coef_)
print(regressor.intercept_)
# Out:
# [0.49]
# 6.391211476101731

# %%
from sklearn.metrics import r2_score
print("R2 Score =", r2_score(y_test, y_pred))
# Out:
# R2 Score = 0.5320101641748491

# %%
print("Coefficients:", regressor.coef_)
print("Intercept:", regressor.intercept_)
# Out:
# Coefficients: [ 0.03 -0.25  0.5   0.5 ]
# Intercept: 6.682729874777408
